# %% [markdown]
# # Brachistochorne Problem
#
# We present the solution to the Brachistochone problem using gekko.

# %%
import numpy as np
import gekko as gk
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %% [markdown]
# Here we define the parameters and, in the following, the gekko formulation

# %%
xf = 4
yf = -2
n_points = 200

# %%
m = gk.GEKKO()
m.time = np.linspace(0, 1, n_points)

A = (0,0)
B = (xf,yf)

# Poition (x,y) of the object
x = m.Var(value=A[0], name='x')
y = m.Var(value=A[1], name='y')

# Velocity of the obtject
v = m.Var(value=0, name='velocity')

# Time variable
tf = m.FV(value=1.0, name='final time', lb=0.1, ub=100.0)
tf.STATUS = 1

# Control function
u = m.MV(value=0, name='acceleration',  lb=-10.0, ub=10.0)
u.STATUS = 1

# Gravity constant
g = m.Const(value=9.81665, name='g')

m.Equation(x.dt() == v*m.sin(u)*tf)
m.Equation(y.dt() == v*m.cos(u)*tf)
m.Equation(v.dt() == -g*m.cos(u)*tf)

obj_points = np.zeros(n_points)
obj_points[-1] = 1.0
final = m.Param(value=obj_points)

# Final constraints 
xf = m.Param()
yf = m.Param()
m.free(xf)
m.free(yf)
m.fix_final(xf, B[0])
m.fix_final(yf, B[1])

m.Equations([xf==x, yf==y])

# Optimal final time
m.Obj(tf)

# Solving
m.options.IMODE = 6
m.options.NODES = 6
m.options.MV_TYPE = 1
m.solve()
# Out:
# apm 201.39.147.24_gk_model0 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.1
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            1
#    Variables    :            8
#    Intermediates:            0
#    Connections  :            6
#    Equations    :            6
#    Residuals    :            6
#
#  Number of state variables:           9752
#  Number of total equations: -         9552
#  Number of slack variables: -            0
#  ---------------------------------------
#  Degrees of freedom       :            200
#
#  **********************************************
#  Dynamic Control with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    39181
# Number of nonzeros in inequality constraint Jacobian.:      796
# Number of nonzeros in Lagrangian Hessian.............:     3980
#
# Total number of variables............................:     9752
#                      variables with only lower bounds:      398
#                 variables with lower and upper bounds:      996
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     9154
# Total number of inequality constraints...............:      398
#         inequality constraints with only lower bounds:      398
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.9500043e+02 9.82e+00 1.00e+02   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.0543407e+02 7.65e+00 4.52e+11  -5.1 7.65e+00  -4.0 9.84e-01 1.00e+00h  1
# Reallocating memory for MA57: lfact (950280)
# Reallocating memory for MA57: lfact (1165524)
# Reallocating memory for MA57: lfact (1270794)
#    2  4.1853561e+02 7.31e+00 6.21e+12  -0.7 1.23e+01   3.8 1.00e+00 4.44e-02h  4
#    3  4.2408576e+02 7.25e+00 6.42e+12  -0.8 1.00e+02   8.8 4.45e-02 8.60e-03h  3
#    4  4.3437538e+02 7.15e+00 7.04e+12  -0.8 4.50e+01   8.3 2.51e-01 1.45e-02h  3
#    5  4.4934900e+02 7.01e+00 8.08e+12  -0.8 2.51e+01   8.7 5.73e-01 1.95e-02h  3
#    6  4.6472663e+02 6.87e+00 8.89e+12  -0.8 1.93e+01   9.2 5.11e-01 1.90e-02h  3
#    7  4.9569418e+02 6.61e+00 1.16e+13  -0.8 1.47e+01   9.6 1.00e+00 3.76e-02h  2
#    8  5.2060660e+02 6.43e+00 1.25e+13  -0.8 2.15e+01   9.1 4.07e-01 2.73e-02h  1
#    9  5.3062089e+02 6.36e+00 1.25e+13  -0.8 1.44e+01   9.5 4.88e-01 1.13e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5
0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.1285852e+03 1.14e-01 2.98e-01 -11.0 2.38e+00  -3.4 1.00e+00 1.00e+00h  1
#   41  1.1313556e+03 4.74e-02 9.57e-02  -9.0 1.13e+00  -3.9 1.00e+00 7.11e-01h  1
#   42  1.1315987e+03 4.06e-02 8.18e-02  -7.1 1.23e+00  -4.4 1.00e+00 1.46e-01h  1
#   43  1.1330519e+03 7.44e-03 3.55e-03  -6.9 7.91e-01  -4.9 1.00e+00 1.00e+00h  1
#   44  1.1331594e+03 8.81e-05 2.10e-06  -7.5 4.79e-01  -5.4 1.00e+00 1.00e+00h  1
#   45  1.1331593e+03 9.94e-06 5.61e-07  -7.9 3.83e-01  -5.8 9.49e-01 1.00e+00h  1
#   46  1.1331593e+03 1.64e-06 1.03e-07  -8.3 2.09e-01  -6.3 1.00e+00 9.98e-01h  1
#   47  1.1331593e+03 8.77e-08 9.08e-09  -9.0 5.20e-02  -6.8 1.00e+00 9.93e-01h  1
#
# Number of Iterations....: 47
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1388535591042503e+02    1.1331592913087291e+03
# Dual infeasibility......:   9.0812323200628340e-09    9.0358261584625186e-08
# Constraint violation....:   8.7701945261642322e-08    8.7701945261642322e-08
# Complementarity.........:   1.9216012322535625e-09    1.9119932260922947e-08
# Overall NLP error.......:   8.7701945261642322e-08    9.0358261584625186e-08
#
#
# Number of objective function evaluations             = 81
# Number of objective gradient evaluations             = 48
# Number of equality constraint evaluations            = 81
# Number of inequality constraint evaluations          = 81
# Number of equality constraint Jacobian evaluations   = 48
# Number of inequality constraint Jacobian evaluations = 48
# Number of Lagrangian Hessian evaluations             = 47
# Total CPU secs in IPOPT (w/o function evaluations)   =      4.443
# Total CPU secs in NLP function evaluations           =      3.625
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is    1133.15929130873
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :    8.35900000001129      sec
#  Objective      :    1133.15929130873
#  Successful solution
#  ---------------------------------------------------

# %%
plt.figure(figsize=(12,6))
plt.grid(linestyle='--', alpha=0.5)

plt.plot(x.value,y.value, 'black', alpha=0.8, label=r'Best curve: $t_f = {:.2f}s$'.format(tf.value[0]))
plt.scatter([A[0], B[0]], [A[1], B[1]], s=50, color='darkblue')
plt.plot([A[0], B[0]], [A[1], B[1]], color='olive', linestyle='--', label='Straight curve: $t_f = {:.2f}s$'.format(1.4246))

plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.legend()
plt.title('Brachistochrone curve', fontsize=20)

plt.text(0.15, 0, 'A', horizontalalignment='center', verticalalignment='center', fontsize=15)
plt.text(4, -1.9, 'B', horizontalalignment='center', verticalalignment='center', fontsize=15)

plt.savefig('../images/brachistochrone.pdf', bbox_inches='tight')
plt.show()

# %% [raw]
# diff_equation = gk.GEKKO()
# diff_equation.time = np.linspace(0, 1.5, n_points)
#
# A = (0,0)
# B = (xf,yf)
#
# # Poition (x,y) of the object
# x = diff_equation.Var(value=A[0], name='x')
# y = diff_equation.Var(value=A[1], name='y')
#
# # Velocity of the obtject
# v = diff_equation.Var(value=0, name='velocity')
# t = diff_equation.Var(0); diff_equation.Equation(t.dt()==1)
#
# # Control function
#
#
# # Gravity constant
# g = diff_equation.Const(value=9.81665, name='g')
#
# diff_equation.Equation(x.dt() == v*m.sin(a*t-b))
# diff_equation.Equation(y.dt() == v*m.cos(a*t-b))
# diff_equation.Equation(v.dt() == -g*m.cos(a*t-b))
#
# # solve ODE
# diff_equation.options.IMODE = 4
# diff_equation.solve(disp=True)

# %% [raw]
# plt.plot(x,y)
